# %%
import pandas as pd
from toolbox.dao.files import FileLoader
from load_from_excel import f_load_input_file
import os

MF = f_load_input_file("examples.xlsx")
#priority_weight = pd.read_excel("./inputs/examples.xlsx", sheet_name='Priority')

# %%
path = "./inputs/examples.xlsx"
FL = FileLoader(path, archive=False)
FL.execute()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 3
#       1 path = "./inputs/examples.xlsx"
#       2 FL = FileLoader(path, archive=False)
# ----> 3 FL.execute()
#
# File /opt/.pyenv/versions/3.11.1/envs/tying_the_rope/src/liam-hsieh-toolbox/toolbox/dao/files/loader.py:229, in FileLoader.execute(self)
#     227         self._load_when_path_is_folder(archive=True)
#     228     elif ftype in self.supported_format:
# --> 229         self._load_to_attrDict([self._input_path,],True,ftype)
#     231 else:
#     232     exception_msg = "path should only point to a directory or a file (could be an archive with optional argument archive = True"
#
# File /opt/.pyenv/versions/3.11.1/envs/tying_the_rope/src/liam-hsieh-toolbox/toolbox/dao/files/loader.py:248, in FileLoader._load_to_attrDict(self, contents, single_file, file_type)
# ...

# %%
import pathlib
pathlib.Path("./inputs/examples.xlsx").suffix
df = pd.read_excel("./inputs/examples.xlsx", sheet_name=None)

# %%
df["Demand"]
# Out:
#    -0.096990    0.449098    1.000000   ...   31.670000   36.624000   34.662000
# 0      0.1644    0.260954          20  ...      1.0410      0.9580       0.953
# 1      0.0317    0.137300           1  ...     16.4710     16.5380      16.421
# 2     -0.0172    0.238500           1  ...     22.6510     25.9950      28.296
# 3     -0.0360    0.168100           1  ...     45.0570     44.3210      43.671
# 4     -0.0360    0.168100          20  ...      2.2080      1.8870       1.633
# 5     -0.0360    0.168100          40  ...      0.0935      0.0649       1.072
# 6      0.0317    0.137300          20  ...      1.2840      1.3770       1.424
# 7      0.0000    0.000000           2  ...      4.5580      4.5650       4.539
# 8     -0.0105    0.172500          40  ...      0.6070      0.6510       0.362
# 9     -0.0105    0.172500         400  ...      0.3080      0.2960       0.305
#
# [10 rows x 11 columns]
